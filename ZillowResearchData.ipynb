# %%
import pandas as pd
from pandas import Series, DataFrame
from itertools import islice

# %%
import os
import glob

Zillow_DIR = os.path.join(os.pardir, "OpenData", "Neighborhood")

assert os.path.exists(Zillow_DIR)

glob.glob(Zillow_DIR + "/*")[:5]
# Out:
# ['..\\OpenData\\Neighborhood\\AllRegionsForePublic.csv',
#  '..\\OpenData\\Neighborhood\\Neighborhood_ForSaleInventorySupply_AllHomes.csv',
#  '..\\OpenData\\Neighborhood\\Neighborhood_HomesSoldAsForeclosures-Ratio_AllHomes.csv',
#  '..\\OpenData\\Neighborhood\\Neighborhood_MedianListingPricePerSqft_AllHomes.csv',
#  '..\\OpenData\\Neighborhood\\Neighborhood_MedianListingPrice_AllHomes.csv']

# %%
homevalue = pd.read_csv("Neighborhood_Zhvi_AllHomes.csv")
homevalue.head()
# Out:
#           RegionName         City State              Metro   CountyName  \
# 0   Northeast Dallas       Dallas    TX  Dallas-Fort Worth       Dallas
# 1           Paradise    Las Vegas    NV          Las Vegas        Clark
# 2    Upper West Side     New York    NY           New York     New York
# 3  South Los Angeles  Los Angeles    CA        Los Angeles  Los Angeles
# 4       Sherman Oaks  Los Angeles    CA        Los Angeles  Los Angeles
#
#    1996-04  1996-05  1996-06  1996-07  1996-08  1996-09  1996-10  1996-11  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1   116400   116500   116800   117000   117100   117400   117600   117600
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3   118800   119900   120900   121100   121000   120900   120600   120700
# 4   146700   145900   145000   144500   144800   145100   145300   145500
#
#    1996-12  1997-01  1997-02  1997-03  1997-04  1997-05  1997-06
# ...

# %%
oakland_homevalue=homevalue[(homevalue.State=='CA') & (homevalue.City=='Oakland')]
oakland_homevalue #from 1996-04 to 2014-02, 72 neighborhoods
# Out:
#                 RegionName     City State          Metro CountyName  1996-04  \
# 1307       Redwood Heights  Oakland    CA  San Francisco    Alameda   185500
# 1481           Adams Point  Oakland    CA  San Francisco    Alameda   113800
# 1531               Clinton  Oakland    CA  San Francisco    Alameda   125200
# 1582     Cleveland Heights  Oakland    CA  San Francisco    Alameda   209900
# 1677           Havenscourt  Oakland    CA  San Francisco    Alameda    94300
# 1740               Bushrod  Oakland    CA  San Francisco    Alameda   169100
# 1760       Piedmont Avenue  Oakland    CA  San Francisco    Alameda   144700
# 1820          Upper Dimond  Oakland    CA  San Francisco    Alameda   170600
# 1826         St. Elizabeth  Oakland    CA  San Francisco    Alameda   106400
# 1972            Longfellow  Oakland    CA  San Francisco    Alameda   134800
# 1990       Upper Rockridge  Oakland    CA  San Francisco    Alameda   350300
# ...

# %%
# Out:
#       2013-12  2014-01  2014-02
# 4530   812800   813300   813400
# 4660  1115100  1118600  1121400
# 4720  1071200  1074900  1078800
# 4809   590600   594100   597000
# 4843   267100   266600   265100
# 4895   719800   722800   723900
# 4898  1018800  1017800  1015200
# 4924   846800   849000   849200
# 5144   177700   180600   183000
#
# [9 rows x 3 columns]
