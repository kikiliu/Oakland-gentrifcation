# %%
# %pylab --no-import-all inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame, Series, Index
import pandas as pd

from itertools import islice

# %%
import census
import us

import settings

# %%
c = census.Census(key=settings.CENSUS_KEY)

# %%
us.states.STATES[4].fips
# Out:
# u'06'

# %%
def tracts(variables='NAME'):
    
    for tract in c.sf1.get((variables), {'for': 'tract:*', 'in': 'state:%s county:%s' % (us.states.STATES[4].fips
, '001')}):
        yield tract
        
    
tracts().next()
# Out:
# {u'NAME': u'Census Tract 4001',
#  u'county': u'001',
#  u'state': u'06',
#  u'tract': u'400100'}

# %%
#P0010001/Total Pop, P0050004/African-American Not Hispanic, P0050010/Hispanic, 
#P0050006/Asian, not Hispanic P0050003/White, not Hispanic 
o_tracts = [tract for tract in tracts(variables="NAME,P0010001,P0050004,P0050010,P0050006,P0050003")]

#add income!!!!!!

#put list into dataframe
tract_df = pd.DataFrame(o_tracts)

# %%
tract_df['African-American, not Hispanic'] = tract_df['P0050004']
tract_df['White, not Hispanic'] = tract_df['P0050003']
tract_df['Asian, not Hispanic'] = tract_df['P0050006']
tract_df['Total Pop'] = tract_df['P0010001']
tract_df['Hispanic'] = tract_df['P0050010']

#show only columns that have legible names; set index by tract
alameda_tracts_df = tract_df[['NAME','tract','Total Pop','African-American, not Hispanic', \
          'Asian, not Hispanic', 'Hispanic', 'White, not Hispanic', 'county','state']].set_index(['tract'])

#sort by income


#transpose so tracts are columns 
alameda_tracts_df.transpose().head()
# Out:
# tract                                      400100             400200  \
# NAME                            Census Tract 4001  Census Tract 4002
# Total Pop                                    2937               1974
# African-American, not Hispanic                140                 31
# Asian, not Hispanic                           456                146
# Hispanic                                      117                151
#
# tract                                      400300             400400  \
# NAME                            Census Tract 4003  Census Tract 4004
# Total Pop                                    4865               3703
# African-American, not Hispanic                512                448
# Asian, not Hispanic                           419                270
# Hispanic                                      399                332
#
# tract                                      400500             400600  \
# NAME                            Census Tract 4005  Census Tract 4006
# Total Pop                                    3517               1571
# African-American, not Hispanic                933                615
# Asian, not Hispanic                           208                 80
# Hispanic                                      340                126
#
# tract                                      400700             400800  \
# NAME                            Census Tract 4007  Census Tract 4008
# Total Pop                                    4206               3594
# African-American, not Hispanic               2068               1463
# Asian, not Hispanic                           249                429
# Hispanic                                      439                367
#
# tract                                      400900             401000  \
# NAME                            Census Tract 4009  Census Tract 4010
# Total Pop                                    2302               5678
# African-American, not Hispanic               1005               2848
# Asian, not Hispanic                           128                418
# Hispanic                                      307                806
#
# tract                                      401100             401200  \
# NAME                            Census Tract 4011  Census Tract 4012
# Total Pop                                    4156               2416
# African-American, not Hispanic                975                421
# Asian, not Hispanic                           439                225
# Hispanic                                      522                226
#
# tract                                      401300             401400  \
# NAME                            Census Tract 4013  Census Tract 4014
# Total Pop                                    3528               4314
# African-American, not Hispanic               1255               2090
# Asian, not Hispanic                           671                427
# Hispanic                                      488                911
#
# tract                                      401500             401600  \
# NAME                            Census Tract 4015  Census Tract 4016
# Total Pop                                    2630               2163
# African-American, not Hispanic               1392               1005
# Asian, not Hispanic                           183                257
# Hispanic                                      406                449
#
# tract                                      401700             401800  \
# NAME                            Census Tract 4017  Census Tract 4018
# Total Pop                                    2667               1703
# African-American, not Hispanic                884                977
# Asian, not Hispanic                           265                 51
# Hispanic                                      683                329
#
# tract                                      402200             402400
# NAME                            Census Tract 4022  Census Tract 4024 ...
# Total Pop                                    2385               2351 ...
# African-American, not Hispanic                868               1358 ...
# Asian, not Hispanic                           271                328 ...
# Hispanic                                      720                220 ...
#
# [5 rows x 361 columns]

# %%
tract_df.P0010001.astype(int).sum()
# Out:
# 1510271

# %%
def places(variables="NAME"):
    
    for state in us.states.STATES:
        geo = {'for':'place:*', 'in':'state:{s_fips}'.format(s_fips=us.states.STATES[4].fips)}
        for place in c.sf1.get(variables, geo=geo):
            yield place

# %%
ca_places = [place for place in places(variables="NAME,P0010001,P0050004,P0050010,P0050006,P0050003")]

#put list into dataframe
ca_places_df = pd.DataFrame(ca_places)
ca_places_df.head()
# Out:
#                  NAME P0010001 P0050003 P0050004 P0050006 P0050010  place  \
# 0  Acalanes Ridge CDP     1137      908        5      125       50  00135
# 1          Acampo CDP      341      113        0        3      199  00156
# 2           Acton CDP     7596     5782       54      151     1373  00212
# 3       Adelanto city    31765     5395     6196      522    18513  00296
# 4            Adin CDP      272      224        2        0       32  00310
#
#   state
# 0    06
# 1    06
# 2    06
# 3    06
# 4    06
#
# [5 rows x 8 columns]

# %%
#turn numbers into integers
ca_places_df.P0010001 = ca_places_df.P0010001.astype(int)
ca_places_df.P0050003 = ca_places_df.P0050003.astype(int)
ca_places_df.P0050004 = ca_places_df.P0050004.astype(int)
ca_places_df.P0050006 = ca_places_df.P0050006.astype(int)
ca_places_df.P0050010 = ca_places_df.P0050010.astype(int)

ca_places_df[['NAME','P0010001','P0050003', 'P0050004','P0050006', 'P0050010']].sort('P0010001', ascending=False).head()
# Out:
#                    NAME  P0010001  P0050003  P0050004  P0050006  P0050010
# 73893  Los Angeles city   3792621   1086908    347380    420212   1838822
# 34295  Los Angeles city   3792621   1086908    347380    420212   1838822
# 72370  Los Angeles city   3792621   1086908    347380    420212   1838822
# 52571  Los Angeles city   3792621   1086908    347380    420212   1838822
# 22111  Los Angeles city   3792621   1086908    347380    420212   1838822
#
# [5 rows x 6 columns]

# %%
ca_places_df.describe()
# Out:
#              P0010001        P0050003       P0050004       P0050006  \
# count    77673.000000    77673.000000   77673.000000   77673.000000
# mean     23101.918582     9016.091924    1385.439265    3079.800394
# std     114959.785922    36938.588559   10421.820816   17490.123392
# min          0.000000        0.000000       0.000000       0.000000
# 25%        646.000000      297.000000       3.000000       5.000000
# 50%       3131.000000     1539.000000      27.000000      54.000000
# 75%      15568.000000     6387.000000     322.000000     752.000000
# max    3792621.000000  1086908.000000  347380.000000  420212.000000
#
#              P0050010
# count    77673.000000
# mean      8793.244255
# std      52360.833513
# min          0.000000
# 25%         91.000000
# 50%        637.000000
# 75%       4829.000000
# max    1838822.000000
#
# [8 rows x 5 columns]

# %%
o_towns = ca_places_df[ca_places_df['NAME'].str.startswith('O')]
o_towns.sort('P0010001', ascending=False).head()
# Out:
#                NAME  P0010001  P0050003  P0050004  P0050006  P0050010  place  \
# 28384  Oakland city    390724    101308    106637     65127     99068  53000
# 61890  Oakland city    390724    101308    106637     65127     99068  53000
# 39045  Oakland city    390724    101308    106637     65127     99068  53000
# 63413  Oakland city    390724    101308    106637     65127     99068  53000
# 37522  Oakland city    390724    101308    106637     65127     99068  53000
#
#       state
# 28384    06
# 61890    06
# 39045    06
# 63413    06
# 37522    06
#
# [5 rows x 8 columns]

# %%
list(islice(tracts(),1))
# Out:
# [{u'NAME': u'Census Tract 4001',
#   u'county': u'001',
#   u'state': u'06',
#   u'tract': u'400100'}]

# %%
# http://api.census.gov/data/2010/sf1?get=P0010001&for=block+group:*&in=state:02+county:170

def block_groups_in_county(variables='NAME,P0010001', state_fips='06', county_fips='001'):
    geo = {'for':'block group:*',
           'in':'state:{s_fips} county:{c_fips}'.format(s_fips=state_fips,
                                                    c_fips=county_fips)}
    for block_group in c.sf1.get(variables, geo=geo):
        yield block_group

# %%
from itertools import islice

list(islice(block_groups_in_county(), 5))

#islice takes iterable things (generators, for loops, other iteration)
#put None in place of 10 above
# Out:
# [{u'NAME': u'Block Group 1',
#   u'P0010001': u'2937',
#   u'block group': u'1',
#   u'county': u'001',
#   u'state': u'06',
#   u'tract': u'400100'},
#  {u'NAME': u'Block Group 1',
#   u'P0010001': u'1018',
#   u'block group': u'1',
#   u'county': u'001',
#   u'state': u'06',
#   u'tract': u'400200'},
#  {u'NAME': u'Block Group 2',
#   u'P0010001': u'956',
#   u'block group': u'2',
#   u'county': u'001',
#   u'state': u'06',
#   u'tract': u'400200'},
#  {u'NAME': u'Block Group 1',
#   u'P0010001': u'1078',
#   u'block group': u'1',
#   u'county': u'001',
#   u'state': u'06',
#   u'tract': u'400300'},
#  {u'NAME': u'Block Group 2',
#   u'P0010001': u'1298',
#   u'block group': u'2',
#   u'county': u'001',
#   u'state': u'06',
#   u'tract': u'400300'}]

# %%
#list comprehension for grabbing data from above function
bgs = [bg for bg in block_groups_in_county(variables="NAME,P0010001,P0050004")]

#put list into dataframe
bg_df = pd.DataFrame(bgs)
bg_df.set_index(['NAME']).transpose()

#working!
# Out:
# NAME        Block Group 1 Block Group 1 Block Group 2 Block Group 1  \
# P0010001             2937          1018           956          1078
# P0050004              140             6            25            39
# block group             1             1             2             1
# county                001           001           001           001
# state                  06            06            06            06
# tract              400100        400200        400200        400300
#
# NAME        Block Group 2 Block Group 3 Block Group 4 Block Group 1  \
# P0010001             1298          1091          1398          1421
# P0050004               90           324            59            58
# block group             2             3             4             1
# county                001           001           001           001
# state                  06            06            06            06
# tract              400300        400300        400300        400400
#
# NAME        Block Group 2 Block Group 3 Block Group 1 Block Group 2  \
# P0010001             1172          1110          2008           822
# P0050004              245           145           475           282
# block group             2             3             1             2
# county                001           001           001           001
# state                  06            06            06            06
# tract              400400        400400        400500        400500
#
# NAME        Block Group 3 Block Group 1 Block Group 2 Block Group 1  \
# P0010001              687           950           621          1078
# P0050004              176           382           233           467
# block group             3             1             2             1
# county                001           001           001           001
# state                  06            06            06            06
# tract              400500        400600        400600        400700
#
# NAME        Block Group 2 Block Group 3 Block Group 4 Block Group 1
# P0010001             1178           724          1226          1268 ...
# P0050004              598           338           665           488 ...
# block group             2             3             4             1 ...
# county                001           001           001           001 ...
# state                  06            06            06            06 ...
# tract              400700        400700        400700        400800 ...
#
# [6 rows x 1047 columns]
