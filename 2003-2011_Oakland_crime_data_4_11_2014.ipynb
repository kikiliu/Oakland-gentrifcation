# %%
from pandas import DataFrame, Series
import pandas as pd

# %%
csv_path = 'C:\Users\User\Documents\IPython Notebooks\OAK_CrimeReports2003to2011.csv'

# %%
df = pd.read_csv(csv_path)
# Out:
# C:\Users\User\Anaconda\envs\myenv\lib\site-packages\pandas\io\parsers.py:1070: DtypeWarning: Columns (5,6,13,22,24,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
dfTemp = df[['RD','DEPARTMENT','ADDRESS','LAT','LONG','ZIP10','TRACTCE00','TRACTCE10']]

# %%
dfTemp[['RD','DEPARTMENT','ADDRESS','LAT','LONG','ZIP10','TRACTCE00','TRACTCE10']] = dfTemp[['RD','DEPARTMENT','ADDRESS','LAT','LONG','ZIP10','TRACTCE00','TRACTCE10']].fillna(value='missing')
# Out:
# C:\Users\User\Anaconda\envs\myenv\lib\site-packages\pandas\core\frame.py:1908: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
#   self[k1] = value[k2]

# %%
dfTemp
# Out:
#            RD                   DEPARTMENT                        ADDRESS  \
# 0   11-048434                  PETTY THEFT                 99 ELDRIDGE AV
# 1   11-058076                        OTHER                   2273 86TH AV
# 2   11-040288                      WEAPONS                    532 44TH ST
# 3   11-060854               STOLEN VEHICLE              1967 COURTLAND AV
# 4   11-060854               STOLEN VEHICLE              1967 COURTLAND AV
# 5   11-035439                    VANDALISM  5900 MARTIN LUTHER KING JR WY
# 6   11-061185               STOLEN VEHICLE   1400 BLOCK  EAST 33RD STREET
# 7   11-062227               STOLEN VEHICLE              900 BROCKHURST ST
# 8   11-062227               STOLEN VEHICLE              900 BROCKHURST ST
# 9   11-062227               STOLEN VEHICLE              900 BROCKHURST ST
# 10  11-062227               STOLEN VEHICLE              900 BROCKHURST ST
# 11  11-061571                      ROBBERY            2247 EAST. 15TH ST.
# ...

# %%
# Next step is to build a generator to fill in the missing data in the Census Tract 2010, and then to aggregate by Census Tract.
